# %%
import pandas as pd
import mytools
from pyreadstat import pyreadstat

# %%
pd.read_csv(R'C:\Users\pc\Desktop\maxiao\output\类别变量练习数据.csv', encoding='GBK', )
# Out:
#               父亲工作  Unnamed: 1  Unnamed: 2  Unnamed: 3 父亲职业重新编码  Unnamed: 5  \
# 0     中铁六局太原铁路建设公司         NaN         NaN         NaN       国企         NaN
# 1       凯信会议服务有限公司         NaN         NaN         NaN       民企         NaN
# 2       银光聚银化工有限公司         NaN         NaN         NaN       国企         NaN
# 3       元拓科技咨询有限公司         NaN         NaN         NaN       民企         NaN
# 4          市广播电视大学         NaN         NaN         NaN     事业单位         NaN
# 5         市经济合作局\n         NaN         NaN         NaN      公务员         NaN
# 6          区建豪汽修中心         NaN         NaN         NaN       个体         NaN
# 7          区建豪汽修中心         NaN         NaN         NaN       个体         NaN
# 8     陕西省水利水电第三工程局         NaN         NaN         NaN       国企         NaN
# 9   渭源陇原恒新畜牧科技有限公司         NaN         NaN         NaN       民企         NaN
# 10            市民政局         NaN         NaN         NaN      公务员         NaN
# ...

# %%
类别变量练习数据=pd.read_csv(R'C:\Users\pc\Desktop\maxiao\output\类别变量练习数据.csv', encoding='GBK', )
tau_y = mytools.goodmanKruska_tau_y(类别变量练习数据,'父亲职业重新编码','母亲职业重新编码')
tau_y
# Out:
# c:\Users\pc\Desktop\maxiao\mytools.py:71: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   F_y = cft['All'][i]
# 0.21249124649859946

# %%
mytools.相关系数强弱判断(tau_y)
# Out:
# '弱相关'

# %%
mytools.制作交叉表(类别变量练习数据,'父亲职业重新编码','母亲职业重新编码')
# Out:
# 母亲职业重新编码  上市民企   个体      事业单位       公务员   国企        民企       All
# 父亲职业重新编码
# 个体         0.0  0.6  0.000000  0.000000  0.0  0.142857  0.105263
# 事业单位       0.0  0.0  0.222222  0.000000  0.0  0.000000  0.052632
# 公务员        0.0  0.0  0.666667  0.785714  0.5  0.428571  0.552632
# 国企         0.0  0.2  0.000000  0.000000  0.5  0.142857  0.078947
# 民企         1.0  0.2  0.111111  0.214286  0.0  0.285714  0.210526

# %%
import matplotlib.pyplot as plt  
result = 类别变量练习数据['父亲职业重新编码'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')  
  
# 显示图形  
plt.show()

# %%
import matplotlib.pyplot as plt  
result = 类别变量练习数据['母亲职业重新编码'].value_counts()
labels =result.index
sizes =result.values
plt.pie(sizes, labels=labels, autopct='%1.1f%%')  
  
# 显示图形  
plt.show()
